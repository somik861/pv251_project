# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Load file

# %%
data = pd.read_csv('../data/full.csv')
print(f'Rows: {data.shape[0]}, Columns: {data.shape[1]}')

data.head()
# Out:
# Rows: 22343, Columns: 128
#        country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  Afghanistan  1900      AFG   4832414.0  NaN                      NaN
# 1  Afghanistan  1901      AFG   4879685.0  NaN                      NaN
# 2  Afghanistan  1902      AFG   4935122.0  NaN                      NaN
# 3  Afghanistan  1903      AFG   4998861.0  NaN                      NaN
# 4  Afghanistan  1904      AFG   5063419.0  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# 0                      NaN  ...               NaN                 NaN
# 1                      NaN  ...               NaN                 NaN
# 2                      NaN  ...               NaN                 NaN
# 3                      NaN  ...               NaN                 NaN
# 4                      NaN  ...               NaN                 NaN
#
#    wind_cons_change_pct  wind_cons_change_twh  wind_consumption  \
# 0                   NaN                   NaN               NaN
# 1                   NaN                   NaN               NaN
# 2                   NaN                   NaN               NaN
# 3                   NaN                   NaN               NaN
# 4                   NaN                   NaN               NaN
#
#    wind_elec_per_capita  wind_electricity  wind_energy_per_capita  \
# 0                   NaN               NaN                     NaN
# 1                   NaN               NaN                     NaN
# 2                   NaN               NaN                     NaN
# 3                   NaN               NaN                     NaN
# 4                   NaN               NaN                     NaN
#
#    wind_share_elec  wind_share_energy
# 0              NaN                NaN
# 1              NaN                NaN
# 2              NaN                NaN
# 3              NaN                NaN
# 4              NaN                NaN
#
# [5 rows x 128 columns]

# %% [markdown]
# ## Patch Kosovo's iso_code

# %%
data.loc[data['country'] == 'Kosovo', 'iso_code'] = 'XKX'

# %% [markdown]
# ## Select only interesting columns

# %%
sources = ['biofuel', 'coal', 'gas', 'hydro', 'nuclear', 'oil', 'solar', 'wind']
cols_to_keep = ['iso_code', 'country', 'year', 'population', 'per_capita_electricity']
# electricity consumption share from sources
cols_to_keep += list(map(lambda x: x + '_share_elec', sources))

data = data[cols_to_keep]
data.head()
# Out:
#   iso_code      country  year  population  per_capita_electricity  \
# 0      AFG  Afghanistan  1900   4832414.0                     NaN
# 1      AFG  Afghanistan  1901   4879685.0                     NaN
# 2      AFG  Afghanistan  1902   4935122.0                     NaN
# 3      AFG  Afghanistan  1903   4998861.0                     NaN
# 4      AFG  Afghanistan  1904   5063419.0                     NaN
#
#    biofuel_share_elec  coal_share_elec  gas_share_elec  hydro_share_elec  \
# 0                 NaN              NaN             NaN               NaN
# 1                 NaN              NaN             NaN               NaN
# 2                 NaN              NaN             NaN               NaN
# 3                 NaN              NaN             NaN               NaN
# 4                 NaN              NaN             NaN               NaN
#
#    nuclear_share_elec  oil_share_elec  solar_share_elec  wind_share_elec
# 0                 NaN             NaN               NaN              NaN
# 1                 NaN             NaN               NaN              NaN
# 2                 NaN             NaN               NaN              NaN
# 3                 NaN             NaN               NaN              NaN
# 4                 NaN             NaN               NaN              NaN

# %% [markdown]
# ## Select only europe countries

# %%
iso_codes = {'ALB', 'AND', 'ARM', 'AUT', 'BEL',
             'BGR', 'BIH', 'BLR', 'CHE', 'CYP',
             'CZE', 'DEU', 'DNK', 'ESP', 'EST',
             'FIN', 'FRA', 'FRO', 'GBR', 'GEO',
             'GRC', 'HRV', 'HUN', 'IMN',
             'IRL', 'ISL', 'ITA', 'LIE', 'LTU',
             'LUX', 'LVA', 'MCO', 'MDA', 'MKD',
             'MLT', 'MNE', 'NLD', 'NOR', 'POL',
             'PRT', 'ROU', 'RUS', 'SMR', 'SRB',
             'SVK', 'SVN', 'SWE', 'TUR', 'UKR',
             'VAT', 'XKX'}

data = data[data['iso_code'].isin(iso_codes)]
data.head()
# Out:
#     iso_code  country  year  population  per_capita_electricity  \
# 417      ALB  Albania  1900    811069.0                     NaN
# 418      ALB  Albania  1901    818784.0                     NaN
# 419      ALB  Albania  1902    826432.0                     NaN
# 420      ALB  Albania  1903    834010.0                     NaN
# 421      ALB  Albania  1904    841658.0                     NaN
#
#      biofuel_share_elec  coal_share_elec  gas_share_elec  hydro_share_elec  \
# 417                 NaN              NaN             NaN               NaN
# 418                 NaN              NaN             NaN               NaN
# 419                 NaN              NaN             NaN               NaN
# 420                 NaN              NaN             NaN               NaN
# 421                 NaN              NaN             NaN               NaN
#
#      nuclear_share_elec  oil_share_elec  solar_share_elec  wind_share_elec
# 417                 NaN             NaN               NaN              NaN
# 418                 NaN             NaN               NaN              NaN
# 419                 NaN             NaN               NaN              NaN
# 420                 NaN             NaN               NaN              NaN
# 421                 NaN             NaN               NaN              NaN

# %%
# number of NaNs in population
population_nans = data['population'].isna().sum()

# number of NaNs per year in statistic data
_header = ['iso_code', 'country', 'year', 'population']
col_size = len(data.drop(columns=_header).columns)
years = set(data['year'])

# dict[year, nan_count]
data_nans: dict[int, int] = {}
for year in years:
    data_nans[year] = data[data['year'] == year].drop(columns=_header).isna().sum().sum()

for year, val in data_nans.items():
    print(f'Year: {year} --> NaNs: {val:4>}/{(data["year"] == year).sum() * col_size}')
# Out:
# Year: 1900 --> NaNs: 198/198
# Year: 1901 --> NaNs: 198/198
# Year: 1902 --> NaNs: 198/198
# Year: 1903 --> NaNs: 198/198
# Year: 1904 --> NaNs: 198/198
# Year: 1905 --> NaNs: 198/198
# Year: 1906 --> NaNs: 198/198
# Year: 1907 --> NaNs: 198/198
# Year: 1908 --> NaNs: 198/198
# Year: 1909 --> NaNs: 198/198
# Year: 1910 --> NaNs: 198/198
# Year: 1911 --> NaNs: 198/198
# Year: 1912 --> NaNs: 198/198
# Year: 1913 --> NaNs: 198/198
# Year: 1914 --> NaNs: 198/198
# Year: 1915 --> NaNs: 198/198
# Year: 1916 --> NaNs: 198/198
# Year: 1917 --> NaNs: 198/198
# Year: 1918 --> NaNs: 198/198
# Year: 1919 --> NaNs: 198/198
# Year: 1920 --> NaNs: 198/198
# Year: 1921 --> NaNs: 198/198
# Year: 1922 --> NaNs: 198/198
# Year: 1923 --> NaNs: 198/198
# Year: 1924 --> NaNs: 198/198
# Year: 1925 --> NaNs: 198/198
# Year: 1926 --> NaNs: 198/198
# Year: 1927 --> NaNs: 198/198
# Year: 1928 --> NaNs: 198/198
# Year: 1929 --> NaNs: 198/198
# Year: 1930 --> NaNs: 198/198
# Year: 1931 --> NaNs: 198/198
# Year: 1932 --> NaNs: 198/198
# Year: 1933 --> NaNs: 198/198
# Year: 1934 --> NaNs: 198/198
# Year: 1935 --> NaNs: 198/198
# Year: 1936 --> NaNs: 198/198
# Year: 1937 --> NaNs: 198/198
# Year: 1938 --> NaNs: 198/198
# Year: 1939 --> NaNs: 198/198
# Year: 1940 --> NaNs: 198/198
# Year: 1941 --> NaNs: 198/198
# Year: 1942 --> NaNs: 198/198
# Year: 1943 --> NaNs: 198/198
# Year: 1944 --> NaNs: 198/198
# Year: 1945 --> NaNs: 198/198
# Year: 1946 --> NaNs: 198/198
# Year: 1947 --> NaNs: 198/198
# Year: 1948 --> NaNs: 198/198
# Year: 1949 --> NaNs: 198/198
# Year: 1950 --> NaNs: 198/198
# Year: 1951 --> NaNs: 198/198
# Year: 1952 --> NaNs: 198/198
# Year: 1953 --> NaNs: 198/198
# Year: 1954 --> NaNs: 198/198
# Year: 1955 --> NaNs: 198/198
# Year: 1956 --> NaNs: 198/198
# Year: 1957 --> NaNs: 198/198
# Year: 1958 --> NaNs: 198/198
# Year: 1959 --> NaNs: 198/198
# Year: 1960 --> NaNs: 198/198
# Year: 1961 --> NaNs: 198/198
# Year: 1962 --> NaNs: 198/198
# Year: 1963 --> NaNs: 198/198
# Year: 1964 --> NaNs: 198/198
# Year: 1965 --> NaNs: 252/252
# Year: 1966 --> NaNs: 252/252
# Year: 1967 --> NaNs: 252/252
# Year: 1968 --> NaNs: 252/252
# Year: 1969 --> NaNs: 252/252
# Year: 1970 --> NaNs: 252/252
# Year: 1971 --> NaNs: 252/252
# Year: 1972 --> NaNs: 252/252
# Year: 1973 --> NaNs: 252/252
# Year: 1974 --> NaNs: 252/252
# Year: 1975 --> NaNs: 252/252
# Year: 1976 --> NaNs: 252/252
# Year: 1977 --> NaNs: 252/252
# Year: 1978 --> NaNs: 252/252
# Year: 1979 --> NaNs: 252/252
# Year: 1980 --> NaNs: 261/261
# Year: 1981 --> NaNs: 261/261
# Year: 1982 --> NaNs: 261/261
# Year: 1983 --> NaNs: 261/261
# Year: 1984 --> NaNs: 261/261
# Year: 1985 --> NaNs: 140/315
# Year: 1986 --> NaNs: 140/315
# Year: 1987 --> NaNs: 140/315
# Year: 1988 --> NaNs: 140/315
# Year: 1989 --> NaNs: 140/315
# Year: 1990 --> NaNs: 18/351
# Year: 1991 --> NaNs: 18/351
# Year: 1992 --> NaNs: 54/387
# Year: 1993 --> NaNs: 54/387
# Year: 1994 --> NaNs: 54/387
# Year: 1995 --> NaNs: 54/387
# Year: 1996 --> NaNs: 54/387
# Year: 1997 --> NaNs: 54/387
# Year: 1998 --> NaNs: 54/387
# Year: 1999 --> NaNs: 54/387
# Year: 2000 --> NaNs: 1/396
# Year: 2001 --> NaNs: 1/396
# Year: 2002 --> NaNs: 1/396
# Year: 2003 --> NaNs: 1/396
# Year: 2004 --> NaNs: 1/396
# Year: 2005 --> NaNs: 1/405
# Year: 2006 --> NaNs: 1/405
# Year: 2007 --> NaNs: 1/405
# Year: 2008 --> NaNs: 1/405
# Year: 2009 --> NaNs: 1/405
# Year: 2010 --> NaNs: 1/405
# Year: 2011 --> NaNs: 1/405
# Year: 2012 --> NaNs: 1/405
# Year: 2013 --> NaNs: 1/405
# Year: 2014 --> NaNs: 1/405
# Year: 2015 --> NaNs: 1/405
# Year: 2016 --> NaNs: 1/405
# Year: 2017 --> NaNs: 1/405
# Year: 2018 --> NaNs: 1/405
# Year: 2019 --> NaNs: 1/405
# Year: 2020 --> NaNs: 1/405
# Year: 2021 --> NaNs: 5/378

# %% [markdown]
# ## Filter out years with only nans

# %%
years_to_keep: set[int] = set()
    
for year, val in data_nans.items():
    if val != (data['year'] == year).sum() * col_size:
        years_to_keep.add(year)
        
data = data[data['year'].isin(years_to_keep)]
data.head()
# Out:
#     iso_code  country  year  population  per_capita_electricity  \
# 502      ALB  Albania  1985   2969671.0                     NaN
# 503      ALB  Albania  1986   3044201.0                     NaN
# 504      ALB  Albania  1987   3124892.0                     NaN
# 505      ALB  Albania  1988   3200972.0                     NaN
# 506      ALB  Albania  1989   3257913.0                     NaN
#
#      biofuel_share_elec  coal_share_elec  gas_share_elec  hydro_share_elec  \
# 502                 NaN              NaN             NaN               NaN
# 503                 NaN              NaN             NaN               NaN
# 504                 NaN              NaN             NaN               NaN
# 505                 NaN              NaN             NaN               NaN
# 506                 NaN              NaN             NaN               NaN
#
#      nuclear_share_elec  oil_share_elec  solar_share_elec  wind_share_elec
# 502                 NaN             NaN               NaN              NaN
# 503                 NaN             NaN               NaN              NaN
# 504                 NaN             NaN               NaN              NaN
# 505                 NaN             NaN               NaN              NaN
# 506                 NaN             NaN               NaN              NaN

# %% [markdown]
# ## Add non-existing rows for Country-year tuple (filled with NaNs)

# %%
min_year = data['year'].min()
max_year = data['year'].max()

countries = set(data['iso_code'])

for year in range(min_year, max_year + 1):
    for iso in countries:
        name = data[data['iso_code'] == iso]['country'].values[0]
        if data.query(f'iso_code == "{iso}" & year == {year}').empty:
            print(f'Inserting: {iso=} {year=}')
            data = pd.concat([data, pd.DataFrame({'iso_code': [iso], 'country': [name],
                        'year': [year]})], axis=0, ignore_index=True)

data.sort_values(by=['country', 'year'],inplace=True)
data.head()
# Out:
# Inserting: iso='MNE' year=1985
# Inserting: iso='HRV' year=1985
# Inserting: iso='XKX' year=1985
# Inserting: iso='BIH' year=1985
# Inserting: iso='SVN' year=1985
# Inserting: iso='MDA' year=1985
# Inserting: iso='MKD' year=1985
# Inserting: iso='GEO' year=1985
# Inserting: iso='SRB' year=1985
# Inserting: iso='ARM' year=1985
# Inserting: iso='MNE' year=1986
# Inserting: iso='HRV' year=1986
# Inserting: iso='XKX' year=1986
# Inserting: iso='BIH' year=1986
# Inserting: iso='SVN' year=1986
# Inserting: iso='MDA' year=1986
# Inserting: iso='MKD' year=1986
# Inserting: iso='GEO' year=1986
# Inserting: iso='SRB' year=1986
# Inserting: iso='ARM' year=1986
# Inserting: iso='MNE' year=1987
# Inserting: iso='HRV' year=1987
# Inserting: iso='XKX' year=1987
# Inserting: iso='BIH' year=1987
# Inserting: iso='SVN' year=1987
# Inserting: iso='MDA' year=1987
# Inserting: iso='MKD' year=1987
# Inserting: iso='GEO' year=1987
# Inserting: iso='SRB' year=1987
# Inserting: iso='ARM' year=1987
# Inserting: iso='MNE' year=1988
# Inserting: iso='HRV' year=1988
# Inserting: iso='XKX' year=1988
# Inserting: iso='BIH' year=1988
# Inserting: iso='SVN' year=1988
# Inserting: iso='MDA' year=1988
# Inserting: iso='MKD' year=1988
# Inserting: iso='GEO' year=1988
# Inserting: iso='SRB' year=1988
# Inserting: iso='ARM' year=1988
# Inserting: iso='MNE' year=1989
# Inserting: iso='HRV' year=1989
# Inserting: iso='XKX' year=1989
# Inserting: iso='BIH' year=1989
# Inserting: iso='SVN' year=1989
# Inserting: iso='MDA' year=1989
# Inserting: iso='MKD' year=1989
# Inserting: iso='GEO' year=1989
# Inserting: iso='SRB' year=1989
# Inserting: iso='ARM' year=1989
# Inserting: iso='MNE' year=1990
# Inserting: iso='XKX' year=1990
# Inserting: iso='BIH' year=1990
# Inserting: iso='MDA' year=1990
# Inserting: iso='GEO' year=1990
# Inserting: iso='ARM' year=1990
# Inserting: iso='MNE' year=1991
# Inserting: iso='XKX' year=1991
# Inserting: iso='BIH' year=1991
# Inserting: iso='MDA' year=1991
# Inserting: iso='GEO' year=1991
# Inserting: iso='ARM' year=1991
# Inserting: iso='MNE' year=1992
# Inserting: iso='XKX' year=1992
# Inserting: iso='MNE' year=1993
# Inserting: iso='XKX' year=1993
# Inserting: iso='MNE' year=1994
# Inserting: iso='XKX' year=1994
# Inserting: iso='MNE' year=1995
# Inserting: iso='XKX' year=1995
# Inserting: iso='MNE' year=1996
# Inserting: iso='XKX' year=1996
# Inserting: iso='MNE' year=1997
# Inserting: iso='XKX' year=1997
# Inserting: iso='MNE' year=1998
# Inserting: iso='XKX' year=1998
# Inserting: iso='MNE' year=1999
# Inserting: iso='XKX' year=1999
# Inserting: iso='MNE' year=2000
# Inserting: iso='MNE' year=2001
# Inserting: iso='MNE' year=2002
# Inserting: iso='MNE' year=2003
# Inserting: iso='MNE' year=2004
# Inserting: iso='ALB' year=2021
# Inserting: iso='XKX' year=2021
# Inserting: iso='FRO' year=2021
#   iso_code  country  year  population  per_capita_electricity  \
# 0      ALB  Albania  1985   2969671.0                     NaN
# 1      ALB  Albania  1986   3044201.0                     NaN
# 2      ALB  Albania  1987   3124892.0                     NaN
# 3      ALB  Albania  1988   3200972.0                     NaN
# 4      ALB  Albania  1989   3257913.0                     NaN
#
#    biofuel_share_elec  coal_share_elec  gas_share_elec  hydro_share_elec  \
# 0                 NaN              NaN             NaN               NaN
# 1                 NaN              NaN             NaN               NaN
# 2                 NaN              NaN             NaN               NaN
# 3                 NaN              NaN             NaN               NaN
# 4                 NaN              NaN             NaN               NaN
#
#    nuclear_share_elec  oil_share_elec  solar_share_elec  wind_share_elec
# 0                 NaN             NaN               NaN              NaN
# 1                 NaN             NaN               NaN              NaN
# 2                 NaN             NaN               NaN              NaN
# 3                 NaN             NaN               NaN              NaN
# 4                 NaN             NaN               NaN              NaN

# %% [markdown]
# ## Normalize share columns

# %%
share_cols = list(col for col in data.columns if 'share_elec' in col)
sums = data[share_cols].sum(axis=1, min_count=len(share_cols))
data[share_cols] = data[share_cols].divide(sums.fillna(100), axis='index') * 100.0

data.head()
# Out:
#   iso_code  country  year  population  per_capita_electricity  \
# 0      ALB  Albania  1985   2969671.0                     NaN
# 1      ALB  Albania  1986   3044201.0                     NaN
# 2      ALB  Albania  1987   3124892.0                     NaN
# 3      ALB  Albania  1988   3200972.0                     NaN
# 4      ALB  Albania  1989   3257913.0                     NaN
#
#    biofuel_share_elec  coal_share_elec  gas_share_elec  hydro_share_elec  \
# 0                 NaN              NaN             NaN               NaN
# 1                 NaN              NaN             NaN               NaN
# 2                 NaN              NaN             NaN               NaN
# 3                 NaN              NaN             NaN               NaN
# 4                 NaN              NaN             NaN               NaN
#
#    nuclear_share_elec  oil_share_elec  solar_share_elec  wind_share_elec
# 0                 NaN             NaN               NaN              NaN
# 1                 NaN             NaN               NaN              NaN
# 2                 NaN             NaN               NaN              NaN
# 3                 NaN             NaN               NaN              NaN
# 4                 NaN             NaN               NaN              NaN

# %% [markdown]
# ## Confirm that shares add up to 100.0

# %%
sums = data[share_cols].sum(axis=1, min_count=len(share_cols))

print(f'Invalid rows: {(~np.isclose(sums.fillna(100), 100.0)).sum()}')
# Out:
# Invalid rows: 0

# %% [markdown]
# ## Rename columns

# %%
name_map = {'per_capita_electricity': 'electricity_perc'}
for source in sources:
    name_map[source + '_share_elec'] = source + '_pct'

data = data.rename(name_map, axis='columns')

# %% [markdown]
# ## Save dataset as json

# %%
import math

data_json = {}
iso_name_json = {}

for row in data.itertuples():
    iso_name_json[row.iso_code] = row.country
    
    iso = row.iso_code
    year = row.year
    
    if iso not in data_json:
        data_json[iso] = {}
        
    assert year not in data_json[iso]
    data_json[iso][year] = {}
    
    all_cols = ['population', 'electricity_perc'] + \
    list(map(lambda x: x + '_pct', sources))
    for col in all_cols:
        val = getattr(row, col)
        if type(val) is float and math.isnan(val):
            val = None
        data_json[iso][year][col] = val 
    
json.dump(data_json, open('../data/filtered.json', 'w'), indent=4)
json.dump(iso_name_json, open('../data/iso_name_map.json', 'w'),indent=4)

# %% [markdown]
# ## Save dataset as csv

# %%
data.to_csv('../data/filtered.csv', index=False)
